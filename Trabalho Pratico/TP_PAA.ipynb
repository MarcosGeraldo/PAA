# %% [markdown]
# ## Geração dos Valores Aleatorios

# %%
import time
from time import perf_counter, sleep
import random as rand
import numpy as np
from numpy.core.memmap import uint8

# %% [markdown]
# Criação do banco de instancias

# %%
iter=20 #Numero de testes para cada tamanho de entrada
maxN = 100 #tamanho inicial

randVec1= [1]*iter #Prenche vetor com 1
for j in range(iter):
  randVec1[j]=[1]*maxN
  for i in range(maxN): #Preenche o vetor com 100 valores aleatorios
        randVec1[j][i] = rand.randint(1,maxN)

maxN*=10
randVec2= [1]*iter #Prenche vetor com 1
for j in range(iter):
  randVec2[j]=[1]*maxN
  for i in range(maxN): #Preenche o vetor com 100 valores aleatorios
        randVec2[j][i] = rand.randint(1,maxN)

maxN*=10
randVec3= [1]*iter #Prenche vetor com 1
for j in range(iter):
  randVec3[j]=[1]*maxN
  for i in range(maxN): #Preenche o vetor com 100 valores aleatorios
        randVec3[j][i] = rand.randint(1,maxN)

maxN*=10
randVec4= [1]*iter #Prenche vetor com 1
for j in range(iter):
  randVec4[j]=[1]*maxN
  for i in range(maxN): #Preenche o vetor com 100 valores aleatorios
        randVec4[j][i] = rand.randint(1,maxN)

maxN*=10
randVec5= [1]*iter #Prenche vetor com 1
for j in range(iter):
  randVec5[j]=[1]*maxN
  for i in range(maxN): #Preenche o vetor com 100 valores aleatorios
        randVec5[j][i] = rand.randint(1,maxN)

maxN*=10
randVec6= [1]*iter #Prenche vetor com 1
for j in range(iter):
  randVec6[j]=[1]*maxN
  for i in range(maxN): #Preenche o vetor com 100 valores aleatorios
        randVec6[j][i] = rand.randint(1,maxN)

#maxN*=10
#randVec7= [1]*maxN #Prenche vetor com 1
#for i in range(maxN): #Preenche o vetor com 1000000 valores aleatorios
#      randVec7[i] = rand.randint(1,maxN)




def getVector(case,test):
  auxVec=[]
  if(case==0):
    auxVec=randVec1[test].copy()
  if(case==1):
    auxVec=randVec2[test].copy()
  if(case==2):
    auxVec=randVec3[test].copy()
  if(case==3):
    auxVec=randVec4[test].copy()
  if(case==4):
    auxVec=randVec5[test].copy()
  if(case==5):
    auxVec=randVec6[test].copy()
  return auxVec.copy()

# %% [markdown]
# # Ordenação Utilizando MergeSort

# %%
def mergeSort(lista):

    if len(lista) > 1:

        meio = len(lista)//2
        #também é valido: meio = int(len(lista)/2)

        listaDaEsquerda = lista[:meio]
        listaDaDireita = lista[meio:]

        mergeSort(listaDaEsquerda)
        mergeSort(listaDaDireita)

        i = 0
        j = 0
        k = 0

        while i < len(listaDaEsquerda) and j < len(listaDaDireita):

            if listaDaEsquerda[i] < listaDaDireita[j]:
                lista[k]=listaDaEsquerda[i]
                i += 1
            else:
                lista[k]=listaDaDireita[j]
                j += 1
            k += 1

        while i < len(listaDaEsquerda):

            lista[k]=listaDaEsquerda[i]
            i += 1
            k += 1

        while j < len(listaDaDireita):
            lista[k]=listaDaDireita[j]
            j += 1
            k += 1
    return lista

# %%
maxN = 100 #tamanho inicial
iter = 20 #Numero de testes para cada tamanho
cases= 4  #Ate qual tamanho de entrada vai se avaliado

randVec=[]

for case in range(cases): #Varia o tamanho de entrada
  for test in range(iter): #Percore 20 instancias distintas

    randVec = getVector(case,test)#Preenche o vetor com valores aleatorios
    #Executa a ordenação

    print("Numero de instancias:",maxN)

    start = perf_counter() #Coleta o inicio
    result = mergeSort(randVec)
    end = perf_counter() #Coleta o Final

    print("Iteração ",test+1,", Tempo total: ",end-start)
    if(test==(iter-1)):
      maxN*=10
# Out:
# Numero de instancias: 100
# Iteração  1 , Tempo total:  0.0003442949998770928
# Numero de instancias: 100
# Iteração  2 , Tempo total:  0.0005764840000210825
# Numero de instancias: 100
# Iteração  3 , Tempo total:  0.0005313889998888044
# Numero de instancias: 100
# Iteração  4 , Tempo total:  0.0005209739999827434
# Numero de instancias: 100
# Iteração  5 , Tempo total:  0.0009196790001624322
# Numero de instancias: 100
# Iteração  6 , Tempo total:  0.0003268929999649117
# Numero de instancias: 100
# Iteração  7 , Tempo total:  0.0003259239999806596
# Numero de instancias: 100
# Iteração  8 , Tempo total:  0.00036549400010699173
# Numero de instancias: 100
# Iteração  9 , Tempo total:  0.00034097300022040145
# Numero de instancias: 100
# Iteração  10 , Tempo total:  0.000346389000014824
# Numero de instancias: 100
# Iteração  11 , Tempo total:  0.00037268599999151775
# Numero de instancias: 100
# Iteração  12 , Tempo total:  0.000341621999950803
# Numero de instancias: 100
# Iteração  13 , Tempo total:  0.0003358149999712623
# Numero de instancias: 100
# Iteração  14 , Tempo total:  0.00034022099998765043
# Numero de instancias: 100
# Iteração  15 , Tempo total:  0.00034064000010403106
# Numero de instancias: 100
# Iteração  16 , Tempo total:  0.00034540699994067836
# Numero de instancias: 100
# Iteração  17 , Tempo total:  0.00034347799987699545
# Numero de instancias: 100
# Iteração  18 , Tempo total:  0.00037096799997016205
# Numero de instancias: 100
# Iteração  19 , Tempo total:  0.00033029500013981306
# Numero de instancias: 100
# Iteração  20 , Tempo total:  0.0003455020000728837
# Numero de instancias: 1000
# Iteração  1 , Tempo total:  0.004686454999955458
# Numero de instancias: 1000
# Iteração  2 , Tempo total:  0.0045517519999975775
# Numero de instancias: 1000
# Iteração  3 , Tempo total:  0.004594759999918097
# Numero de instancias: 1000
# Iteração  4 , Tempo total:  0.005939132999856156
# Numero de instancias: 1000
# Iteração  5 , Tempo total:  0.004917460999877221
# Numero de instancias: 1000
# Iteração  6 , Tempo total:  0.0047742090000610915
# Numero de instancias: 1000
# Iteração  7 , Tempo total:  0.004636892999997144
# Numero de instancias: 1000
# Iteração  8 , Tempo total:  0.004608655000083672
# Numero de instancias: 1000
# Iteração  9 , Tempo total:  0.004804330000069967
# Numero de instancias: 1000
# Iteração  10 , Tempo total:  0.004602909999903204
# Numero de instancias: 1000
# Iteração  11 , Tempo total:  0.00467107000008582
# Numero de instancias: 1000
# Iteração  12 , Tempo total:  0.00454481100018711
# Numero de instancias: 1000
# Iteração  13 , Tempo total:  0.004812291999996887
# Numero de instancias: 1000
# Iteração  14 , Tempo total:  0.004544997000039075
# Numero de instancias: 1000
# Iteração  15 , Tempo total:  0.004524060999983703
# Numero de instancias: 1000
# Iteração  16 , Tempo total:  0.004508910000140531
# Numero de instancias: 1000
# Iteração  17 , Tempo total:  0.004521237999824734
# Numero de instancias: 1000
# Iteração  18 , Tempo total:  0.004462773000113884
# Numero de instancias: 1000
# Iteração  19 , Tempo total:  0.0044952849998480815
# Numero de instancias: 1000
# Iteração  20 , Tempo total:  0.004511086000093201
# Numero de instancias: 10000
# Iteração  1 , Tempo total:  0.07746540600010121
# Numero de instancias: 10000
# Iteração  2 , Tempo total:  0.08114730600004805
# Numero de instancias: 10000
# Iteração  3 , Tempo total:  0.07318785300003583
# Numero de instancias: 10000
# Iteração  4 , Tempo total:  0.07669245900001442
# Numero de instancias: 10000
# Iteração  5 , Tempo total:  0.10378674800017507
# Numero de instancias: 10000
# Iteração  6 , Tempo total:  0.07641587800003435
# Numero de instancias: 10000
# Iteração  7 , Tempo total:  0.09443179300001248
# Numero de instancias: 10000
# Iteração  8 , Tempo total:  0.08728893200009225
# Numero de instancias: 10000
# Iteração  9 , Tempo total:  0.0654504359999919
# Numero de instancias: 10000
# Iteração  10 , Tempo total:  0.07596998599979088
# Numero de instancias: 10000
# Iteração  11 , Tempo total:  0.06530968300012319
# Numero de instancias: 10000
# Iteração  12 , Tempo total:  0.06887208299986014
# Numero de instancias: 10000
# Iteração  13 , Tempo total:  0.06327092399988032
# Numero de instancias: 10000
# Iteração  14 , Tempo total:  0.07355642500010617
# Numero de instancias: 10000
# Iteração  15 , Tempo total:  0.06572111199989195
# Numero de instancias: 10000
# Iteração  16 , Tempo total:  0.06588061200000084
# Numero de instancias: 10000
# Iteração  17 , Tempo total:  0.06480957600001602
# Numero de instancias: 10000
# Iteração  18 , Tempo total:  0.08118293500001528
# Numero de instancias: 10000
# Iteração  19 , Tempo total:  0.06515964799996254
# Numero de instancias: 10000
# Iteração  20 , Tempo total:  0.06375792900007582
# Numero de instancias: 100000
# Iteração  1 , Tempo total:  0.8161872069999845
# Numero de instancias: 100000
# Iteração  2 , Tempo total:  0.7928158450001774
# Numero de instancias: 100000
# Iteração  3 , Tempo total:  0.8091321290000906
# Numero de instancias: 100000
# Iteração  4 , Tempo total:  0.8033557820001533
# Numero de instancias: 100000
# Iteração  5 , Tempo total:  0.7841469009999855
# Numero de instancias: 100000
# Iteração  6 , Tempo total:  0.8017637269999796
# Numero de instancias: 100000
# Iteração  7 , Tempo total:  0.8068827269999019
# Numero de instancias: 100000
# Iteração  8 , Tempo total:  0.8121120060000067
# Numero de instancias: 100000
# Iteração  9 , Tempo total:  0.7980052139998861
# Numero de instancias: 100000
# Iteração  10 , Tempo total:  0.8092367419999391
# Numero de instancias: 100000
# Iteração  11 , Tempo total:  0.8092160720000265
# Numero de instancias: 100000
# Iteração  12 , Tempo total:  0.8006935660000636
# Numero de instancias: 100000
# Iteração  13 , Tempo total:  0.8112795320000714
# Numero de instancias: 100000
# Iteração  14 , Tempo total:  0.793877934999955
# Numero de instancias: 100000
# Iteração  15 , Tempo total:  0.8066557930001181
# Numero de instancias: 100000
# Iteração  16 , Tempo total:  0.803388588999951
# Numero de instancias: 100000
# Iteração  17 , Tempo total:  0.8090938860000279
# Numero de instancias: 100000
# Iteração  18 , Tempo total:  0.8030449430000317
# Numero de instancias: 100000
# Iteração  19 , Tempo total:  0.7991626390000874
# Numero de instancias: 100000
# Iteração  20 , Tempo total:  0.7933444800000871

# %% [markdown]
# # Ordenação utilizando SelectionSort

# %%
def selectionSort(lista):
  for i in range(len(lista)):

    menor = i

    for j in range(i+1,len(lista)):

        if lista[j] < lista[menor]:

                menor = j

    if lista[i] != lista[menor]:

            aux = lista[i]

            lista[i] = lista[menor]

            lista[menor] = aux

# %%
maxN = 100 #tamanho inicial
iter = 20 #Numero de testes para cada tamanho
cases= 3  #Ate qual tamanho de entrada vai se avaliado

randVec=[]

for case in range(cases): #Varia o tamanho de entrada
  for test in range(iter): #Percore 20 instancias distintas
    
    randVec = getVector(case,test)#Preenche o vetor com valores aleatorios

    print("Numero de instancias:",maxN)#Executa a ordenação


    start = perf_counter() #Coleta o inicio
    result = selectionSort(randVec)
    end = perf_counter() #Coleta o Final

    print("Iteração ",test+1,", Tempo total: ",end-start)
    if(test==(iter-1)):
      maxN*=10
# Out:
# Numero de instancias: 100
# Iteração  1 , Tempo total:  0.0007450260000041453
# Numero de instancias: 100
# Iteração  2 , Tempo total:  0.0004208750001453154
# Numero de instancias: 100
# Iteração  3 , Tempo total:  0.0004413720000684407
# Numero de instancias: 100
# Iteração  4 , Tempo total:  0.000482852000004641
# Numero de instancias: 100
# Iteração  5 , Tempo total:  0.000446278000026723
# Numero de instancias: 100
# Iteração  6 , Tempo total:  0.00045423799997479364
# Numero de instancias: 100
# Iteração  7 , Tempo total:  0.00048188499999923806
# Numero de instancias: 100
# Iteração  8 , Tempo total:  0.0004732279999188904
# Numero de instancias: 100
# Iteração  9 , Tempo total:  0.0005909679998694628
# Numero de instancias: 100
# Iteração  10 , Tempo total:  0.0007795049998549075
# Numero de instancias: 100
# Iteração  11 , Tempo total:  0.00047674699999333825
# Numero de instancias: 100
# Iteração  12 , Tempo total:  0.0004442540000582085
# Numero de instancias: 100
# Iteração  13 , Tempo total:  0.00045095900009073375
# Numero de instancias: 100
# Iteração  14 , Tempo total:  0.0004273829999874579
# Numero de instancias: 100
# Iteração  15 , Tempo total:  0.0004393020001316472
# Numero de instancias: 100
# Iteração  16 , Tempo total:  0.0004537759998584079
# Numero de instancias: 100
# Iteração  17 , Tempo total:  0.0004355579999355541
# Numero de instancias: 100
# Iteração  18 , Tempo total:  0.0004433120000157942
# Numero de instancias: 100
# Iteração  19 , Tempo total:  0.0004644549999284209
# Numero de instancias: 100
# Iteração  20 , Tempo total:  0.0004337870000199473
# Numero de instancias: 1000
# Iteração  1 , Tempo total:  0.0531885529999272
# Numero de instancias: 1000
# Iteração  2 , Tempo total:  0.053534024000100544
# Numero de instancias: 1000
# Iteração  3 , Tempo total:  0.05331782200005364
# Numero de instancias: 1000
# Iteração  4 , Tempo total:  0.05767182999989018
# Numero de instancias: 1000
# Iteração  5 , Tempo total:  0.056666452000172285
# Numero de instancias: 1000
# Iteração  6 , Tempo total:  0.04482402300004651
# Numero de instancias: 1000
# Iteração  7 , Tempo total:  0.05543351500000426
# Numero de instancias: 1000
# Iteração  8 , Tempo total:  0.0464435979999962
# Numero de instancias: 1000
# Iteração  9 , Tempo total:  0.04985869200004345
# Numero de instancias: 1000
# Iteração  10 , Tempo total:  0.046617056000059165
# Numero de instancias: 1000
# Iteração  11 , Tempo total:  0.048563793999846894
# Numero de instancias: 1000
# Iteração  12 , Tempo total:  0.052240879000009954
# Numero de instancias: 1000
# Iteração  13 , Tempo total:  0.05331539100006921
# Numero de instancias: 1000
# Iteração  14 , Tempo total:  0.04686789900006261
# Numero de instancias: 1000
# Iteração  15 , Tempo total:  0.053917970000156856
# Numero de instancias: 1000
# Iteração  16 , Tempo total:  0.045136358000036125
# Numero de instancias: 1000
# Iteração  17 , Tempo total:  0.049206311000034475
# Numero de instancias: 1000
# Iteração  18 , Tempo total:  0.05622506200006683
# Numero de instancias: 1000
# Iteração  19 , Tempo total:  0.041912545000059254
# Numero de instancias: 1000
# Iteração  20 , Tempo total:  0.04471557400006532
# Numero de instancias: 10000
# Iteração  1 , Tempo total:  4.33665932100007
# Numero de instancias: 10000
# Iteração  2 , Tempo total:  4.259559066000065
# Numero de instancias: 10000
# Iteração  3 , Tempo total:  4.261361255000111
# Numero de instancias: 10000
# Iteração  4 , Tempo total:  4.193159723000008
# Numero de instancias: 10000
# Iteração  5 , Tempo total:  4.268118108999943
# Numero de instancias: 10000
# Iteração  6 , Tempo total:  4.273765039999944
# Numero de instancias: 10000
# Iteração  7 , Tempo total:  4.2320160249998935
# Numero de instancias: 10000
# Iteração  8 , Tempo total:  4.212627658999963
# Numero de instancias: 10000
# Iteração  9 , Tempo total:  4.1614913769999475
# Numero de instancias: 10000
# Iteração  10 , Tempo total:  4.180062206999992
# Numero de instancias: 10000
# Iteração  11 , Tempo total:  4.19482677499991
# Numero de instancias: 10000
# Iteração  12 , Tempo total:  4.212616947000015
# Numero de instancias: 10000
# Iteração  13 , Tempo total:  4.293800409999903
# Numero de instancias: 10000
# Iteração  14 , Tempo total:  4.2751923560001615
# Numero de instancias: 10000
# Iteração  15 , Tempo total:  4.24151590800011
# Numero de instancias: 10000
# Iteração  16 , Tempo total:  4.192657327999996
# Numero de instancias: 10000
# Iteração  17 , Tempo total:  4.194242857999825
# Numero de instancias: 10000
# Iteração  18 , Tempo total:  4.177561124000022
# Numero de instancias: 10000
# Iteração  19 , Tempo total:  4.199439036000058
# Numero de instancias: 10000
# Iteração  20 , Tempo total:  4.307166494999819

# %% [markdown]
# # Ordenação Utilziando RadixSort

# %%
MAX_CHARS = 28

def radix_sort(lista):
        tamanho_maximo = max([len(str(palavra)) for palavra in lista])

        for pos in range(tamanho_maximo*1, 1, -1):
                baldes = [list() for y in range(MAX_CHARS)]
                for palavra in lista:
                        balde = numero_do_balde(palavra, pos)
                        baldes[balde] += [palavra]
                lista = sum(baldes, [])

        return lista

def numero_do_balde(palavra, pos):
        if (pos >= len(str(palavra))): return 0
        ch = str(palavra)[pos]
        if (ch >= 'A' and ch <= 'Z'): return ord(ch) - ord('A') + 1
        if (ch >= 'a' and ch <= 'z'): return ord(ch) - ord('a') + 1
        return MAX_CHARS-1

# %%
maxN = 100 #tamanho inicial
iter = 20 #Numero de testes para cada tamanho
cases= 5  #Ate qual tamanho de entrada vai se avaliado

randVec=[]

for case in range(cases): #Varia o tamanho de entrada
  for test in range(iter): #Percore 20 instancias distintas
    
    randVec = getVector(case,test)#Preenche o vetor com valores aleatorios

    print("Numero de instancias:",maxN)

    start = perf_counter() #Coleta o inicio

    result = radix_sort(randVec)#Executa a ordenação

    end = perf_counter() #Coleta o Final

    print("Iteração ",test+1,", Tempo total: ",end-start)
    if(test==(iter-1)):
      maxN*=10
# Out:
# Numero de instancias: 100
# Iteração  1 , Tempo total:  0.00036017599995830096
# Numero de instancias: 100
# Iteração  2 , Tempo total:  0.00015779500017742976
# Numero de instancias: 100
# Iteração  3 , Tempo total:  0.00015288099984900327
# Numero de instancias: 100
# Iteração  4 , Tempo total:  0.0001417599996784702
# Numero de instancias: 100
# Iteração  5 , Tempo total:  8.21990001895756e-05
# Numero de instancias: 100
# Iteração  6 , Tempo total:  0.0001177919998553989
# Numero de instancias: 100
# Iteração  7 , Tempo total:  0.00015226300001813797
# Numero de instancias: 100
# Iteração  8 , Tempo total:  9.839999984251335e-05
# Numero de instancias: 100
# Iteração  9 , Tempo total:  0.0001305199998569151
# Numero de instancias: 100
# Iteração  10 , Tempo total:  0.00017943500006367685
# Numero de instancias: 100
# Iteração  11 , Tempo total:  0.00017402999992555124
# Numero de instancias: 100
# Iteração  12 , Tempo total:  0.00017878399967230507
# Numero de instancias: 100
# Iteração  13 , Tempo total:  0.00011590000030992087
# Numero de instancias: 100
# Iteração  14 , Tempo total:  0.00012418599999364233
# Numero de instancias: 100
# Iteração  15 , Tempo total:  0.00011424200010878849
# Numero de instancias: 100
# Iteração  16 , Tempo total:  0.00017660499997873558
# Numero de instancias: 100
# Iteração  17 , Tempo total:  0.00020226500009812298
# Numero de instancias: 100
# Iteração  18 , Tempo total:  0.0001698340001894394
# Numero de instancias: 100
# Iteração  19 , Tempo total:  0.00016599999980826396
# Numero de instancias: 100
# Iteração  20 , Tempo total:  0.00017439900011595455
# Numero de instancias: 1000
# Iteração  1 , Tempo total:  0.0023220379998747376
# Numero de instancias: 1000
# Iteração  2 , Tempo total:  0.00185907800005225
# Numero de instancias: 1000
# Iteração  3 , Tempo total:  0.0016366410000046017
# Numero de instancias: 1000
# Iteração  4 , Tempo total:  0.0015533810001215898
# Numero de instancias: 1000
# Iteração  5 , Tempo total:  0.0015668870000808965
# Numero de instancias: 1000
# Iteração  6 , Tempo total:  0.001548137000099814
# Numero de instancias: 1000
# Iteração  7 , Tempo total:  0.0018943850000141538
# Numero de instancias: 1000
# Iteração  8 , Tempo total:  0.002059469999949215
# Numero de instancias: 1000
# Iteração  9 , Tempo total:  0.0021235730000626063
# Numero de instancias: 1000
# Iteração  10 , Tempo total:  0.0020250460001989268
# Numero de instancias: 1000
# Iteração  11 , Tempo total:  0.0015647109999008535
# Numero de instancias: 1000
# Iteração  12 , Tempo total:  0.002009662000091339
# Numero de instancias: 1000
# Iteração  13 , Tempo total:  0.0015062970001054055
# Numero de instancias: 1000
# Iteração  14 , Tempo total:  0.0015512059999309713
# Numero de instancias: 1000
# Iteração  15 , Tempo total:  0.002014667999901576
# Numero de instancias: 1000
# Iteração  16 , Tempo total:  0.0015573119999316987
# Numero de instancias: 1000
# Iteração  17 , Tempo total:  0.002056908999747975
# Numero de instancias: 1000
# Iteração  18 , Tempo total:  0.002010439000059705
# Numero de instancias: 1000
# Iteração  19 , Tempo total:  0.001532049999696028
# Numero de instancias: 1000
# Iteração  20 , Tempo total:  0.002058569000382704
# Numero de instancias: 10000
# Iteração  1 , Tempo total:  0.029334523000215995
# Numero de instancias: 10000
# Iteração  2 , Tempo total:  0.02744833299993843
# Numero de instancias: 10000
# Iteração  3 , Tempo total:  0.027288475999739603
# Numero de instancias: 10000
# Iteração  4 , Tempo total:  0.03525642200020229
# Numero de instancias: 10000
# Iteração  5 , Tempo total:  0.03487024500009284
# Numero de instancias: 10000
# Iteração  6 , Tempo total:  0.03184015899978476
# Numero de instancias: 10000
# Iteração  7 , Tempo total:  0.037968481999996584
# Numero de instancias: 10000
# Iteração  8 , Tempo total:  0.030242303000250104
# Numero de instancias: 10000
# Iteração  9 , Tempo total:  0.03326648499978546
# Numero de instancias: 10000
# Iteração  10 , Tempo total:  0.04371881899987784
# Numero de instancias: 10000
# Iteração  11 , Tempo total:  0.03590102600037426
# Numero de instancias: 10000
# Iteração  12 , Tempo total:  0.04202678100000412
# Numero de instancias: 10000
# Iteração  13 , Tempo total:  0.04263786999990771
# Numero de instancias: 10000
# Iteração  14 , Tempo total:  0.031208786999741278
# Numero de instancias: 10000
# Iteração  15 , Tempo total:  0.04299554699991859
# Numero de instancias: 10000
# Iteração  16 , Tempo total:  0.03337452599998869
# Numero de instancias: 10000
# Iteração  17 , Tempo total:  0.03409032900026432
# Numero de instancias: 10000
# Iteração  18 , Tempo total:  0.02662174499982939
# Numero de instancias: 10000
# Iteração  19 , Tempo total:  0.032981300999836094
# Numero de instancias: 10000
# Iteração  20 , Tempo total:  0.029067629000110173
# Numero de instancias: 100000
# Iteração  1 , Tempo total:  0.3454909909996786
# Numero de instancias: 100000
# Iteração  2 , Tempo total:  0.42039863200034233
# Numero de instancias: 100000
# Iteração  3 , Tempo total:  0.43249764400025015
# Numero de instancias: 100000
# Iteração  4 , Tempo total:  0.34441664199994193
# Numero de instancias: 100000
# Iteração  5 , Tempo total:  0.40840354399961143
# Numero de instancias: 100000
# Iteração  6 , Tempo total:  0.41992635899987363
# Numero de instancias: 100000
# Iteração  7 , Tempo total:  0.3922423680000975
# Numero de instancias: 100000
# Iteração  8 , Tempo total:  0.4222726870002589
# Numero de instancias: 100000
# Iteração  9 , Tempo total:  0.4078777029999401
# Numero de instancias: 100000
# Iteração  10 , Tempo total:  0.4030012270000043
# Numero de instancias: 100000
# Iteração  11 , Tempo total:  0.40516152899999724
# Numero de instancias: 100000
# Iteração  12 , Tempo total:  0.3379340270003013
# Numero de instancias: 100000
# Iteração  13 , Tempo total:  0.4178273359998457
# Numero de instancias: 100000
# Iteração  14 , Tempo total:  0.34692998500031536
# Numero de instancias: 100000
# Iteração  15 , Tempo total:  0.3949835299999904
# Numero de instancias: 100000
# Iteração  16 , Tempo total:  0.4158344419997775
# Numero de instancias: 100000
# Iteração  17 , Tempo total:  0.3982231549998687
# Numero de instancias: 100000
# Iteração  18 , Tempo total:  0.3701375780001399
# Numero de instancias: 100000
# Iteração  19 , Tempo total:  0.39718081499995606
# Numero de instancias: 100000
# Iteração  20 , Tempo total:  0.39938660699999673
# Numero de instancias: 1000000
# Iteração  1 , Tempo total:  5.245538114000283
# Numero de instancias: 1000000
# Iteração  2 , Tempo total:  5.230382504999852
# Numero de instancias: 1000000
# Iteração  3 , Tempo total:  5.248935393000011
# Numero de instancias: 1000000
# Iteração  4 , Tempo total:  4.467201025000122
# Numero de instancias: 1000000
# Iteração  5 , Tempo total:  5.2323293449999255
# Numero de instancias: 1000000
# Iteração  6 , Tempo total:  5.282648433999839
# Numero de instancias: 1000000
# Iteração  7 , Tempo total:  5.292813727000066
# Numero de instancias: 1000000
# Iteração  8 , Tempo total:  4.466976152999905
# Numero de instancias: 1000000
# Iteração  9 , Tempo total:  5.220670858999711
# Numero de instancias: 1000000
# Iteração  10 , Tempo total:  4.469117947000086
# Numero de instancias: 1000000
# Iteração  11 , Tempo total:  5.228090547000193
# Numero de instancias: 1000000
# Iteração  12 , Tempo total:  5.257706826000231
# Numero de instancias: 1000000
# Iteração  13 , Tempo total:  5.236494915000094
# Numero de instancias: 1000000
# Iteração  14 , Tempo total:  5.264026787999683
# Numero de instancias: 1000000
# Iteração  15 , Tempo total:  5.24744865699995
# Numero de instancias: 1000000
# Iteração  16 , Tempo total:  5.205356922000192
# Numero de instancias: 1000000
# Iteração  17 , Tempo total:  5.30670595599986
# Numero de instancias: 1000000
# Iteração  18 , Tempo total:  5.231903011999748
# Numero de instancias: 1000000
# Iteração  19 , Tempo total:  5.235172373999831
# Numero de instancias: 1000000
# Iteração  20 , Tempo total:  5.258287215000109
